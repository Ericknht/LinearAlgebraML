# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run '../Funciones_auxiliares/graficarVectores.ipynb'
# %run '../Funciones_auxiliares/graficarMatriz.ipynb'

# %%
A = np.array([[3, 7], [5, 2]])

print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
print('Circulo unitario:')
graficarMatriz(np.array([[1, 0],[0, 1]]))

plt.xlim(-1.5, 3)
plt.ylim(-1.5, 1.5)
plt.show()
# Out:
# Circulo unitario:

# %%
print('Circulo unitario transformado:')
graficarMatriz(A)

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show()
# Out:
# Circulo unitario transformado:

# %%
print('Circulo unitario:')
graficarMatriz2(np.array([[1, 0],[0, 1]]))

plt.xlim(-1.5, 3)
plt.ylim(-1.5, 1.5)
plt.show()
# Out:
# Circulo unitario:

# %%
print('Circulo unitario transformado:')
graficarMatriz2(A)

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show()
# Out:
# Circulo unitario transformado:

# %%
U, D, V = np.linalg.svd(A)
D
# Out:
# array([8.71337969, 3.32821489])

# %%
print('Circulo unitario:')
graficarMatriz2(np.array([[1, 0],[0, 1]]))

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Primer rotacion V:')
graficarMatriz2(V)

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Escala D:')
graficarMatriz2(np.diag(D).dot(V))

plt.xlim(-9, 9)
plt.ylim(-9, 9)
plt.show()

print('Segunda Rotacion U:')
graficarMatriz2(U.dot(np.diag(D).dot(V)))

plt.xlim(-9, 9)
plt.ylim(-9, 9)
plt.show()
# Out:
# Circulo unitario:
# Primer rotacion V:
# Escala D:
# Segunda Rotacion U:
